# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# $$Descripción de los Datos$$
#
# La tabla $VISITS$ (registros del servidor con datos sobre las visitas al sitio web):
#
# -$Uid:$ identificador único del usuario.
#
# -$Device:$ dispositivo del usuario.
#
# -$Start Ts:$ fecha y hora de inicio de la sesión.
#
# -$End Ts:$ fecha y hora de término de la sesión.
#
# -$Source Id:$ identificador de la fuente de anuncios de la que proviene el usuario.
# Todas las fechas de esta tabla están en formato AAAA-MM-DD.
#
# La tabla $ORDERS$ (datos sobre pedidos):
#
# -$Uid:$ identificador único del usuario que realiza un pedido.
#
# -$Buy Ts:$ fecha y hora del pedido. Revenue: el ingreso de Showz por el pedido.
#
# La tabla $COSTS$ (datos sobre gastos de marketing):
#
# -$source_id:$ identificador de la fuente de anuncios.
#
# -$dt:$ fecha.
#
# -$costs:$ gastos en esta fuente de anuncios en este día.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# DATASETS

# %%
visits=pd.read_csv('/datasets/visits_log_us.csv')
orders=pd.read_csv('/datasets/orders_log_us.csv')
costs=pd.read_csv('/datasets/costs_us.csv')

# %% [markdown]
# VISITAS

# %%
visits
# Out:
#          Device               End Ts  Source Id             Start Ts  \
# 0         touch  2017-12-20 17:38:00          4  2017-12-20 17:20:00
# 1       desktop  2018-02-19 17:21:00          2  2018-02-19 16:53:00
# 2         touch  2017-07-01 01:54:00          5  2017-07-01 01:54:00
# 3       desktop  2018-05-20 11:23:00          9  2018-05-20 10:59:00
# 4       desktop  2017-12-27 14:06:00          3  2017-12-27 14:06:00
# ...         ...                  ...        ...                  ...
# 359395  desktop  2017-07-29 19:07:19          2  2017-07-29 19:07:00
# 359396    touch  2018-01-25 17:38:19          1  2018-01-25 17:38:00
# 359397  desktop  2018-03-03 10:12:19          4  2018-03-03 10:12:00
# 359398  desktop  2017-11-02 10:12:19          5  2017-11-02 10:12:00
# 359399    touch  2017-09-10 13:13:19          2  2017-09-10 13:13:00
#
#                          Uid
# 0       16879256277535980062
# 1         104060357244891740
# 2        7459035603376831527
# ...

# %%
print(visits.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Device     359400 non-null  object
#  1   End Ts     359400 non-null  object
#  2   Source Id  359400 non-null  int64
#  3   Start Ts   359400 non-null  object
#  4   Uid        359400 non-null  uint64
# dtypes: int64(1), object(3), uint64(1)
# memory usage: 13.7+ MB
# None

# %%
visits.head()
# Out:
#     Device               End Ts  Source Id             Start Ts  \
# 0    touch  2017-12-20 17:38:00          4  2017-12-20 17:20:00
# 1  desktop  2018-02-19 17:21:00          2  2018-02-19 16:53:00
# 2    touch  2017-07-01 01:54:00          5  2017-07-01 01:54:00
# 3  desktop  2018-05-20 11:23:00          9  2018-05-20 10:59:00
# 4  desktop  2017-12-27 14:06:00          3  2017-12-27 14:06:00
#
#                     Uid
# 0  16879256277535980062
# 1    104060357244891740
# 2   7459035603376831527
# 3  16174680259334210214
# 4   9969694820036681168

# %%
#convertir a formato fechas
visits['Start Ts']=pd.to_datetime(visits['Start Ts'])
visits['End Ts']=pd.to_datetime(visits['End Ts'])

# %%
#extraer formatos
visits['sesion_mes']=visits['Start Ts'].dt.to_period('M').dt.start_time
visits['sesion_semana']=visits['Start Ts'].dt.isocalendar().week
visits['sesion_dia']=visits['Start Ts'].dt.date

# %%
visits.head()
# Out:
#     Device              End Ts  Source Id            Start Ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
#
#                     Uid sesion_mes  sesion_semana  sesion_dia
# 0  16879256277535980062 2017-12-01             51  2017-12-20
# 1    104060357244891740 2018-02-01              8  2018-02-19
# 2   7459035603376831527 2017-07-01             26  2017-07-01
# 3  16174680259334210214 2018-05-01             20  2018-05-20
# 4   9969694820036681168 2017-12-01             52  2017-12-27

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Device         359400 non-null  object
#  1   End Ts         359400 non-null  datetime64[ns]
#  2   Source Id      359400 non-null  int64
#  3   Start Ts       359400 non-null  datetime64[ns]
#  4   Uid            359400 non-null  uint64
#  5   sesion_mes     359400 non-null  datetime64[ns]
#  6   sesion_semana  359400 non-null  UInt32
#  7   sesion_dia     359400 non-null  object
# dtypes: UInt32(1), datetime64[ns](3), int64(1), object(2), uint64(1)
# memory usage: 20.9+ MB

# %%
visits['Start Ts'].value_counts()
# Out:
# 2017-11-24 16:06:00    19
# 2018-05-31 10:01:00    15
# 2017-11-24 17:21:00    15
# 2017-11-24 17:19:00    15
# 2017-11-24 16:05:00    14
#                        ..
# 2017-06-23 13:09:00     1
# 2017-11-06 13:29:00     1
# 2017-06-13 23:30:00     1
# 2018-03-21 08:31:00     1
# 2017-07-01 01:17:00     1
# Name: Start Ts, Length: 224303, dtype: int64

# %%
#DAU(DIA), WAU(SEMANA) Y MAU( MES) 
dau=visits.groupby('sesion_dia').agg({'Uid':'nunique'})
wau=visits.groupby('sesion_semana').agg({'Uid':'nunique'})
mau=visits.groupby('sesion_mes').agg({'Uid':'nunique'})
print('DAU',dau.mean())
print()
print('WAU',wau.mean())
print()
print('MAU',mau.mean())
# Out:
# DAU Uid    907.991758
# dtype: float64
#
# WAU Uid    5825.288462
# dtype: float64
#
# MAU Uid    23228.416667
# dtype: float64

# %%
#graficar
dau.plot(color='red')
wau.plot(color='green')
mau.plot(color='blue')
# Out:
# <AxesSubplot:xlabel='sesion_mes'>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Muy bien implementado el cálculo de DAU (Daily Active Users), WAU (Weekly Active Users) y MAU (Monthly Active Users). El uso de `groupby` y `nunique` demuestra que comprendes la lógica detrás de estas métricas. Además, las visualizaciones son apropiadas para detectar tendencias en el tiempo.
#
# Estas métricas son cruciales para evaluar el engagement de los usuarios, y su inclusión aquí fortalece el análisis del comportamiento de uso. ¡Buen trabajo técnico y estratégico!
#
# </div>

# %% [markdown]
# $1.2¿Cuántas sesiones hay por día? (Un usuario puede tener más de una sesión).$

# %%
sesiones_por_dia=visits.groupby('sesion_dia').agg({'Uid':['count','nunique']})
sesiones_por_dia.columns=['n_sesiones', 'n_usuarios']
sesiones_por_dia
# Out:
#             n_sesiones  n_usuarios
# sesion_dia
# 2017-06-01         664         605
# 2017-06-02         658         608
# 2017-06-03         477         445
# 2017-06-04         510         476
# 2017-06-05         893         820
# ...                ...         ...
# 2018-05-27         672         620
# 2018-05-28        1156        1039
# 2018-05-29        1035         948
# 2018-05-30        1410        1289
# 2018-05-31        2256        1997
#
# [364 rows x 2 columns]

# %%
#PROPORCION
sesiones_por_dia['sesion_por_usuario']=sesiones_por_dia['n_sesiones']/sesiones_por_dia['n_usuarios']
sesiones_por_dia.head()
# Out:
#             n_sesiones  n_usuarios  sesion_por_usuario
# sesion_dia
# 2017-06-01         664         605            1.097521
# 2017-06-02         658         608            1.082237
# 2017-06-03         477         445            1.071910
# 2017-06-04         510         476            1.071429
# 2017-06-05         893         820            1.089024

# %%
#graficar
sesiones_por_dia['sesion_por_usuario'].plot()
# Out:
# <AxesSubplot:xlabel='sesion_dia'>

# %% [markdown]
# 1.3¿Cuál es la duración de cada sesión?

# %%
visits['duracion_sesions']=(visits['End Ts'] - visits['Start Ts']).dt.seconds
visits['duracion_sesions'].describe()
# Out:
# count    359400.000000
# mean        643.506489
# std        1016.334786
# min           0.000000
# 25%         120.000000
# 50%         300.000000
# 75%         840.000000
# max       84480.000000
# Name: duracion_sesions, dtype: float64

# %%
#graficar
visits['duracion_sesions'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Device            359400 non-null  object
#  1   End Ts            359400 non-null  datetime64[ns]
#  2   Source Id         359400 non-null  int64
#  3   Start Ts          359400 non-null  datetime64[ns]
#  4   Uid               359400 non-null  uint64
#  5   sesion_mes        359400 non-null  datetime64[ns]
#  6   sesion_semana     359400 non-null  UInt32
#  7   sesion_dia        359400 non-null  object
#  8   duracion_sesions  359400 non-null  int64
# dtypes: UInt32(1), datetime64[ns](3), int64(2), object(2), uint64(1)
# memory usage: 23.6+ MB

# %% [markdown]
# $1.4¿Con qué frecuencia los usuarios regresan? /Tasa de retencion$

# %%
visits
# Out:
#          Device              End Ts  Source Id            Start Ts  \
# 0         touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1       desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2         touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3       desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4       desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
# ...         ...                 ...        ...                 ...
# 359395  desktop 2017-07-29 19:07:19          2 2017-07-29 19:07:00
# 359396    touch 2018-01-25 17:38:19          1 2018-01-25 17:38:00
# 359397  desktop 2018-03-03 10:12:19          4 2018-03-03 10:12:00
# 359398  desktop 2017-11-02 10:12:19          5 2017-11-02 10:12:00
# 359399    touch 2017-09-10 13:13:19          2 2017-09-10 13:13:00
#
#                          Uid sesion_mes  sesion_semana  sesion_dia  \
# 0       16879256277535980062 2017-12-01             51  2017-12-20
# ...

# %% [markdown]
# como nesistamos calacular la tasa de retencion haremos un analisis por cohortes:
# 1. sacar fechas de la primer secion de cada usuario(generar tabla de primera visita)
# 2. enriqueser tabla de primeras fechas con fecha completa y fecha pormes(enriqueser tabla de primera visita con la columna de mes)
# 3. enriqueser tabla de visitas con nueva columna de secion por mes
# 4. merge en tabla de primera visita con tabla de visita atraves de uid
# 5. enqriqueser tabl final con nueva columna llamda age month que es resultado de la resta del mes de la mes ac tual  menos mes de la primera seccion

# %% [markdown]
# 1.cuando fue la primeraves

# %%
primer_visit=visits.groupby('Uid').agg({'Start Ts':'min'}).reset_index()
primer_visit.columns=['Uid','primera_sesion_ts']
primer_visit
# Out:
#                          Uid   primera_sesion_ts
# 0             11863502262781 2018-03-01 17:27:00
# 1             49537067089222 2018-02-06 15:55:00
# 2            297729379853735 2017-06-07 18:47:00
# 3            313578113262317 2017-09-18 22:49:00
# 4            325320750514679 2017-09-30 14:29:00
# ...                      ...                 ...
# 228164  18446403737806311543 2017-11-30 03:36:00
# 228165  18446424184725333426 2017-12-06 20:32:00
# 228166  18446556406699109058 2018-01-01 16:29:00
# 228167  18446621818809592527 2017-12-27 13:27:00
# 228168  18446676030785672386 2017-10-04 16:01:00
#
# [228169 rows x 2 columns]

# %%
#1.4.2extraermes y dia
primer_visit['primer_sesion_dia']=primer_visit['primera_sesion_ts'].dt.date
primer_visit['primer_sesion_mes']=primer_visit['primera_sesion_ts'].dt.to_period('M').dt.start_time

# %% [markdown]
# cuantas veces regresan ($porcentajes$)

# %%
primer_visit.head()
# Out:
#                Uid   primera_sesion_ts primer_sesion_dia primer_sesion_mes
# 0   11863502262781 2018-03-01 17:27:00        2018-03-01        2018-03-01
# 1   49537067089222 2018-02-06 15:55:00        2018-02-06        2018-02-01
# 2  297729379853735 2017-06-07 18:47:00        2017-06-07        2017-06-01
# 3  313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
# 4  325320750514679 2017-09-30 14:29:00        2017-09-30        2017-09-01

# %%
visits
# Out:
#          Device              End Ts  Source Id            Start Ts  \
# 0         touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1       desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2         touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3       desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4       desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
# ...         ...                 ...        ...                 ...
# 359395  desktop 2017-07-29 19:07:19          2 2017-07-29 19:07:00
# 359396    touch 2018-01-25 17:38:19          1 2018-01-25 17:38:00
# 359397  desktop 2018-03-03 10:12:19          4 2018-03-03 10:12:00
# 359398  desktop 2017-11-02 10:12:19          5 2017-11-02 10:12:00
# 359399    touch 2017-09-10 13:13:19          2 2017-09-10 13:13:00
#
#                          Uid sesion_mes  sesion_semana  sesion_dia  \
# 0       16879256277535980062 2017-12-01             51  2017-12-20
# ...

# %%
#1.4.4Fucinar datos
visits_completo=pd.merge(primer_visit, visits, on='Uid')
visits_completo.head()
# Out:
#                Uid   primera_sesion_ts primer_sesion_dia primer_sesion_mes  \
# 0   11863502262781 2018-03-01 17:27:00        2018-03-01        2018-03-01
# 1   49537067089222 2018-02-06 15:55:00        2018-02-06        2018-02-01
# 2  297729379853735 2017-06-07 18:47:00        2017-06-07        2017-06-01
# 3  313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
# 4  313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
#
#     Device              End Ts  Source Id            Start Ts sesion_mes  \
# 0    touch 2018-03-01 17:33:00          3 2018-03-01 17:27:00 2018-03-01
# 1    touch 2018-02-06 15:57:00          2 2018-02-06 15:55:00 2018-02-01
# 2  desktop 2017-06-07 18:48:00          3 2017-06-07 18:47:00 2017-06-01
# 3  desktop 2018-03-11 17:29:00          2 2018-03-11 17:23:00 2018-03-01
# 4  desktop 2017-09-18 23:07:00          2 2017-09-18 22:49:00 2017-09-01
#
#    sesion_semana  sesion_dia  duracion_sesions
# ...

# %%
#1.4.5enqriqueser tabla final con nueva columna llamda age month que es resultado de la resta del mes de la mes actual menos mes de la primera seccion
visits_completo['age_month']=((visits_completo['sesion_mes'] - visits_completo['primer_sesion_mes']).dt.days/30).round().astype('int')
visits_completo
# Out:
#                          Uid   primera_sesion_ts primer_sesion_dia  \
# 0             11863502262781 2018-03-01 17:27:00        2018-03-01
# 1             49537067089222 2018-02-06 15:55:00        2018-02-06
# 2            297729379853735 2017-06-07 18:47:00        2017-06-07
# 3            313578113262317 2017-09-18 22:49:00        2017-09-18
# 4            313578113262317 2017-09-18 22:49:00        2017-09-18
# ...                      ...                 ...               ...
# 359395  18446424184725333426 2017-12-06 20:32:00        2017-12-06
# 359396  18446556406699109058 2018-01-01 16:29:00        2018-01-01
# 359397  18446621818809592527 2017-12-27 13:27:00        2017-12-27
# 359398  18446621818809592527 2017-12-27 13:27:00        2017-12-27
# 359399  18446676030785672386 2017-10-04 16:01:00        2017-10-04
#
#        primer_sesion_mes   Device              End Ts  Source Id  \
# 0             2018-03-01    touch 2018-03-01 17:33:00          3
# ...

# %%
#analisis por cohorte
tabla_cohorte=visits_completo.pivot_table(index='primer_sesion_mes',columns='age_month',values='Uid',aggfunc='nunique')
tabla_cohorte.fillna('')
# Out:
# age_month               0       1       2       3      4      5      6   \
# primer_sesion_mes
# 2017-06-01         13259.0  1043.0   713.0   814.0  909.0  947.0  809.0
# 2017-07-01         13140.0   737.0   674.0   738.0  765.0  633.0  596.0
# 2017-08-01         10181.0   783.0   640.0   639.0  510.0  448.0  370.0
# 2017-09-01         16704.0  1428.0  1156.0   847.0  658.0  632.0  599.0
# 2017-10-01         25977.0  2042.0  1357.0  1012.0  890.0  837.0  555.0
# 2017-11-01         27248.0  2133.0  1202.0  1054.0  919.0  638.0  594.0
# 2017-12-01         25268.0  1410.0   960.0   786.0  512.0  481.0
# 2018-01-01         22624.0  1351.0   890.0   565.0  458.0
# 2018-02-01         22197.0  1267.0   565.0   446.0
# 2018-03-01         20589.0   861.0   557.0
# 2018-04-01         15709.0   760.0
# 2018-05-01         15273.0
#
# age_month             7      8      9      10     11
# primer_sesion_mes
# 2017-06-01         766.0  694.0  674.0  539.0  596.0
# ...

# %% [markdown]
# 2.1 $Ventas$:
# ¿Cuándo empieza la gente a comprar? (En el análisis de $KPI$, ($Indicador Clave de Rendimiento$) generalmente nos interesa saber el tiempo que transcurre entre el registro y la conversión, es decir, cuando el usuario se convierte en cliente. Por ejemplo, si el registro y la primera compra ocurren el mismo día, el usuario podría caer en la categoría Conversion 0d. Si la primera compra ocurre al día siguiente, será Conversion 1d. Puedes usar cualquier enfoque que te permita comparar las conversiones de diferentes cohortes para que puedas determinar qué cohorte o canal de marketing es más efectivo.)

# %% [markdown]
# ORDENES

# %%
orders
# Out:
#                     Buy Ts  Revenue                   Uid
# 0      2017-06-01 00:10:00    17.00  10329302124590727494
# 1      2017-06-01 00:25:00     0.55  11627257723692907447
# 2      2017-06-01 00:27:00     0.37  17903680561304213844
# 3      2017-06-01 00:29:00     0.55  16109239769442553005
# 4      2017-06-01 07:58:00     0.37  14200605875248379450
# ...                    ...      ...                   ...
# 50410  2018-05-31 23:50:00     4.64  12296626599487328624
# 50411  2018-05-31 23:50:00     5.80  11369640365507475976
# 50412  2018-05-31 23:54:00     0.30   1786462140797698849
# 50413  2018-05-31 23:56:00     3.67   3993697860786194247
# 50414  2018-06-01 00:02:00     3.42     83872787173869366
#
# [50415 rows x 3 columns]

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Buy Ts   50415 non-null  object
#  1   Revenue  50415 non-null  float64
#  2   Uid      50415 non-null  uint64
# dtypes: float64(1), object(1), uint64(1)
# memory usage: 1.2+ MB

# %%
orders.head()
# Out:
#                 Buy Ts  Revenue                   Uid
# 0  2017-06-01 00:10:00    17.00  10329302124590727494
# 1  2017-06-01 00:25:00     0.55  11627257723692907447
# 2  2017-06-01 00:27:00     0.37  17903680561304213844
# 3  2017-06-01 00:29:00     0.55  16109239769442553005
# 4  2017-06-01 07:58:00     0.37  14200605875248379450

# %%
#extracion y convercion de fechas
orders['buy_dt']=pd.to_datetime(orders['Buy Ts']).dt.date
orders['order_month']=pd.to_datetime(orders['Buy Ts']).dt.to_period('M')
orders['Buy Ts']=pd.to_datetime(orders['Buy Ts'])
orders.head()
# Out:
#                Buy Ts  Revenue                   Uid      buy_dt order_month
# 0 2017-06-01 00:10:00    17.00  10329302124590727494  2017-06-01     2017-06
# 1 2017-06-01 00:25:00     0.55  11627257723692907447  2017-06-01     2017-06
# 2 2017-06-01 00:27:00     0.37  17903680561304213844  2017-06-01     2017-06
# 3 2017-06-01 00:29:00     0.55  16109239769442553005  2017-06-01     2017-06
# 4 2017-06-01 07:58:00     0.37  14200605875248379450  2017-06-01     2017-06

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Buy Ts       50415 non-null  datetime64[ns]
#  1   Revenue      50415 non-null  float64
#  2   Uid          50415 non-null  uint64
#  3   buy_dt       50415 non-null  object
#  4   order_month  50415 non-null  period[M]
# dtypes: datetime64[ns](1), float64(1), object(1), period[M](1), uint64(1)
# memory usage: 1.9+ MB

# %%
#primeras ordenes
primeras_ordenes=orders.groupby('Uid').agg({'Buy Ts':'min'}).reset_index()
primeras_ordenes.columns=['Uid', 'first_orders_ts']
primeras_ordenes.head()
# Out:
#                 Uid     first_orders_ts
# 0   313578113262317 2018-01-03 21:51:00
# 1  1575281904278712 2017-06-03 10:13:00
# 2  2429014661409475 2017-10-11 18:33:00
# 3  2464366381792757 2018-01-28 15:54:00
# 4  2551852515556206 2017-11-24 10:14:00

# %%
primeras_ordenes['first_orders_dt']=primeras_ordenes['first_orders_ts'].dt.date
primeras_ordenes['first_orders_month']=primeras_ordenes['first_orders_ts'].dt.to_period('M')
primeras_ordenes.head()
# Out:
#                 Uid     first_orders_ts first_orders_dt first_orders_month
# 0   313578113262317 2018-01-03 21:51:00      2018-01-03            2018-01
# 1  1575281904278712 2017-06-03 10:13:00      2017-06-03            2017-06
# 2  2429014661409475 2017-10-11 18:33:00      2017-10-11            2017-10
# 3  2464366381792757 2018-01-28 15:54:00      2018-01-28            2018-01
# 4  2551852515556206 2017-11-24 10:14:00      2017-11-24            2017-11

# %%
#analizar KPI el usuario podría caer en la categoría Conversion 0d. Si la primera compra ocurre al día siguiente, será Conversion 1d.
compradores = pd.merge(primer_visit, primeras_ordenes, on='Uid', how='inner')
compradores
#conversion['tiempo_hasta_compra'] = (conversion['primera_compra'] - conversion['primera_visita']).dt
# Out:
#                         Uid   primera_sesion_ts primer_sesion_dia  \
# 0           313578113262317 2017-09-18 22:49:00        2017-09-18
# 1          1575281904278712 2017-06-03 10:13:00        2017-06-03
# 2          2429014661409475 2017-10-11 17:14:00        2017-10-11
# 3          2464366381792757 2018-01-27 20:10:00        2018-01-27
# 4          2551852515556206 2017-11-24 10:14:00        2017-11-24
# ...                     ...                 ...               ...
# 36518  18445147675727495770 2017-08-20 13:30:00        2017-08-20
# 36519  18445407535914413204 2017-09-22 23:48:00        2017-09-22
# 36520  18445601152732270159 2017-08-07 11:51:00        2017-08-07
# 36521  18446156210226471712 2017-11-07 10:01:00        2017-11-07
# 36522  18446167067214817906 2017-10-17 10:05:00        2017-10-17
#
#       primer_sesion_mes     first_orders_ts first_orders_dt first_orders_month
# 0            2017-09-01 2018-01-03 21:51:00      2018-01-03            2018-01
# ...

# %%
compradores['first_orders_dt']=pd.to_datetime(compradores['first_orders_dt'])
compradores['primer_sesion_dia']=pd.to_datetime(compradores['primer_sesion_dia'])
compradores.head()
# Out:
#                 Uid   primera_sesion_ts primer_sesion_dia primer_sesion_mes  \
# 0   313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
# 1  1575281904278712 2017-06-03 10:13:00        2017-06-03        2017-06-01
# 2  2429014661409475 2017-10-11 17:14:00        2017-10-11        2017-10-01
# 3  2464366381792757 2018-01-27 20:10:00        2018-01-27        2018-01-01
# 4  2551852515556206 2017-11-24 10:14:00        2017-11-24        2017-11-01
#
#       first_orders_ts first_orders_dt first_orders_month
# 0 2018-01-03 21:51:00      2018-01-03            2018-01
# 1 2017-06-03 10:13:00      2017-06-03            2017-06
# 2 2017-10-11 18:33:00      2017-10-11            2017-10
# 3 2018-01-28 15:54:00      2018-01-28            2018-01
# 4 2017-11-24 10:14:00      2017-11-24            2017-11

# %%
compradores['dias_primera_compra']=((compradores['first_orders_ts'] - compradores['primera_sesion_ts'])/np.timedelta64(1,'D')).astype('int')
compradores.head()
# Out:
#                 Uid   primera_sesion_ts primer_sesion_dia primer_sesion_mes  \
# 0   313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
# 1  1575281904278712 2017-06-03 10:13:00        2017-06-03        2017-06-01
# 2  2429014661409475 2017-10-11 17:14:00        2017-10-11        2017-10-01
# 3  2464366381792757 2018-01-27 20:10:00        2018-01-27        2018-01-01
# 4  2551852515556206 2017-11-24 10:14:00        2017-11-24        2017-11-01
#
#       first_orders_ts first_orders_dt first_orders_month  dias_primera_compra
# 0 2018-01-03 21:51:00      2018-01-03            2018-01                  106
# 1 2017-06-03 10:13:00      2017-06-03            2017-06                    0
# 2 2017-10-11 18:33:00      2017-10-11            2017-10                    0
# 3 2018-01-28 15:54:00      2018-01-28            2018-01                    0
# 4 2017-11-24 10:14:00      2017-11-24            2017-11                    0

# %%
compradores['dias_primera_compra'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# $2.2$¿Cuántos pedidos hacen durante un período de tiempo dado?

# %%
cohort_size=compradores.groupby('first_orders_month').agg({'Uid':'nunique'}).reset_index()
cohort_size.rename(columns={'Uid':'n_buyers'},inplace=True)
cohort_size.head()
# Out:
#   first_orders_month  n_buyers
# 0            2017-06      2023
# 1            2017-07      1923
# 2            2017-08      1370
# 3            2017-09      2581
# 4            2017-10      4340

# %%
#cohortsmerge
cohort=pd.merge(orders,compradores)
cohort.head()
# Out:
#                Buy Ts  Revenue                   Uid      buy_dt order_month  \
# 0 2017-06-01 00:10:00    17.00  10329302124590727494  2017-06-01     2017-06
# 1 2017-06-01 00:25:00     0.55  11627257723692907447  2017-06-01     2017-06
# 2 2017-06-01 00:27:00     0.37  17903680561304213844  2017-06-01     2017-06
# 3 2017-06-01 00:29:00     0.55  16109239769442553005  2017-06-01     2017-06
# 4 2017-06-01 07:58:00     0.37  14200605875248379450  2017-06-01     2017-06
#
#     primera_sesion_ts primer_sesion_dia primer_sesion_mes     first_orders_ts  \
# 0 2017-06-01 00:09:00        2017-06-01        2017-06-01 2017-06-01 00:10:00
# 1 2017-06-01 00:14:00        2017-06-01        2017-06-01 2017-06-01 00:25:00
# 2 2017-06-01 00:25:00        2017-06-01        2017-06-01 2017-06-01 00:27:00
# 3 2017-06-01 00:14:00        2017-06-01        2017-06-01 2017-06-01 00:29:00
# 4 2017-06-01 07:31:00        2017-06-01        2017-06-01 2017-06-01 07:58:00
#
# ...

# %%
cohort=cohort.groupby(['first_orders_month', 'order_month']).agg({'Revenue':'count'}).reset_index()
cohort.rename(columns={'Revenue':'n_orders'},inplace=True)

# %%
cohort['ciclo_de_vida']=(cohort['order_month'] - cohort['first_orders_month']).apply(lambda x:x.n)
cohort.head()
# Out:
#   first_orders_month order_month  n_orders  ciclo_de_vida
# 0            2017-06     2017-06      2354              0
# 1            2017-06     2017-07       177              1
# 2            2017-06     2017-08       174              2
# 3            2017-06     2017-09       226              3
# 4            2017-06     2017-10       292              4

# %%
report_cohort=pd.merge(cohort_size,cohort)
report_cohort.head()
# Out:
#   first_orders_month  n_buyers order_month  n_orders  ciclo_de_vida
# 0            2017-06      2023     2017-06      2354              0
# 1            2017-06      2023     2017-07       177              1
# 2            2017-06      2023     2017-08       174              2
# 3            2017-06      2023     2017-09       226              3
# 4            2017-06      2023     2017-10       292              4

# %%
report_cohort['orders_buyer']=report_cohort['n_orders']/report_cohort['n_buyers']
report_cohort.head()
# Out:
#   first_orders_month  n_buyers order_month  n_orders  ciclo_de_vida  \
# 0            2017-06      2023     2017-06      2354              0
# 1            2017-06      2023     2017-07       177              1
# 2            2017-06      2023     2017-08       174              2
# 3            2017-06      2023     2017-09       226              3
# 4            2017-06      2023     2017-10       292              4
#
#    orders_buyer
# 0      1.163618
# 1      0.087494
# 2      0.086011
# 3      0.111715
# 4      0.144340

# %%
analisis_cohort_pivot=report_cohort.pivot_table(
    index='first_orders_month',
    columns='ciclo_de_vida',
    values='orders_buyer',
    aggfunc='sum'
).cumsum(axis=1)
analisis_cohort_pivot.round(2).fillna("")
# Out:
# ciclo_de_vida         0     1     2     3     4     5     6     7     8   \
# first_orders_month
# 2017-06             1.16  1.25  1.34  1.45  1.59   1.7  1.84  1.92  2.03
# 2017-07             1.14  1.19  1.25  1.31  1.34  1.39  1.42  1.44  1.47
# 2017-08             1.12   1.2  1.27  1.33  1.39  1.44  1.47  1.53  1.56
# 2017-09             1.14  1.22  1.28  1.35  1.37  1.42  1.46  1.48   1.5
# 2017-10             1.14  1.22  1.25  1.28  1.31  1.34  1.35  1.38
# 2017-11             1.18  1.28  1.32  1.37  1.41  1.42  1.45
# 2017-12             1.15  1.21  1.26   1.3  1.32  1.34
# 2018-01             1.12  1.19  1.24  1.25  1.28
# 2018-02             1.12  1.18  1.21  1.22
# 2018-03             1.17  1.22  1.27
# 2018-04             1.10  1.18
# 2018-05             1.09
# 2018-06             1.00
#
# ciclo_de_vida         9     10    11
# first_orders_month
# 2017-06              2.1  2.15  2.19
# 2017-07             1.49  1.51
# 2017-08              1.6
# 2017-09
# 2017-10
# ...

# %% [markdown]
# $2.3$¿Cuál es el tamaño promedio de compra?

# %%
print('promedio_de_compra')
orders['Revenue'].mean()
# Out:
# promedio_de_compra
# 4.999646930477041

# %%
orders.pivot_table(
    index='order_month',
    values='Revenue',
    aggfunc='mean'
)
# Out:
#               Revenue
# order_month
# 2017-06      4.060106
# 2017-07      5.306589
# 2017-08      4.847139
# 2017-09      5.416448
# 2017-10      4.928280
# 2017-11      4.783518
# 2017-12      5.852139
# 2018-01      4.112927
# 2018-02      4.840095
# 2018-03      5.413930
# 2018-04      5.150645
# 2018-05      4.771279
# 2018-06      3.420000

# %%
orders.pivot_table(
    index='order_month',
    values='Revenue',
    aggfunc='mean'
).plot(legend=None).set(
    title='promedio de compras por mes',
    xlabel='mes',
    ylabel='promedio de ingresos'
)
plt.show()

# %% [markdown]
# valor del ciclo de vida del cliente)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente enfoque para analizar la evolución del comportamiento de compra. Has utilizado correctamente `pivot_table` para evaluar el promedio de ingresos por mes y `groupby` para analizar la frecuencia de pedidos por cohorte y ciclo de vida.
#
# Además, el cálculo de pedidos por usuario a lo largo del tiempo (con `orders_buyer`) y su representación acumulada permite obtener una visión clara del compromiso del cliente. Esto es clave para determinar el potencial de ingresos recurrentes. Las visualizaciones, aunque básicas, cumplen su función y son fáciles de interpretar.
#
#
#
# </div>

# %% [markdown]
# 2.4¿Cuánto dinero traen? ($LTV$)

# %%
# Fórmula simple de LTV = ingreso_promedio * frecuencia * tiempo_de_vida
#orders['LTV'] = df['promedio de compras por mes'] * df['frecuencia'] * df['tiempo_de_vida']

# %%
primer_visit.head()
# Out:
#                Uid   primera_sesion_ts primer_sesion_dia primer_sesion_mes
# 0   11863502262781 2018-03-01 17:27:00        2018-03-01        2018-03-01
# 1   49537067089222 2018-02-06 15:55:00        2018-02-06        2018-02-01
# 2  297729379853735 2017-06-07 18:47:00        2017-06-07        2017-06-01
# 3  313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
# 4  325320750514679 2017-09-30 14:29:00        2017-09-30        2017-09-01

# %%
orders.head()
# Out:
#                Buy Ts  Revenue                   Uid      buy_dt order_month
# 0 2017-06-01 00:10:00    17.00  10329302124590727494  2017-06-01     2017-06
# 1 2017-06-01 00:25:00     0.55  11627257723692907447  2017-06-01     2017-06
# 2 2017-06-01 00:27:00     0.37  17903680561304213844  2017-06-01     2017-06
# 3 2017-06-01 00:29:00     0.55  16109239769442553005  2017-06-01     2017-06
# 4 2017-06-01 07:58:00     0.37  14200605875248379450  2017-06-01     2017-06

# %%
revenue_users=orders.groupby('Uid')['Revenue'].sum().reset_index(name='total_revenue')
revenue_users
# Out:
#                         Uid  total_revenue
# 0           313578113262317           0.55
# 1          1575281904278712           3.05
# 2          2429014661409475          73.33
# 3          2464366381792757           2.44
# 4          2551852515556206          10.99
# ...                     ...            ...
# 36518  18445147675727495770           3.05
# 36519  18445407535914413204           0.88
# 36520  18445601152732270159           4.22
# 36521  18446156210226471712           9.78
# 36522  18446167067214817906           7.94
#
# [36523 rows x 2 columns]

# %%
# Unir ordenes con la cohorte de cada usuario
orders_cohorte = pd.merge(revenue_users, primer_visit[['Uid', 'primer_sesion_mes']], on='Uid')

orders_cohorte.head()
# Out:
#                 Uid  total_revenue primer_sesion_mes
# 0   313578113262317           0.55        2017-09-01
# 1  1575281904278712           3.05        2017-06-01
# 2  2429014661409475          73.33        2017-10-01
# 3  2464366381792757           2.44        2018-01-01
# 4  2551852515556206          10.99        2017-11-01

# %%
#agrupacion LTV POR COHORTE en pri
df_ltv=orders_cohorte.groupby('primer_sesion_mes').agg(
                total_revenue=('total_revenue', 'sum'),
                total_users=('Uid', 'nunique'),
            ).reset_index()

# %%
df_ltv
# Out:
#    primer_sesion_mes  total_revenue  total_users
# 0         2017-06-01       40026.05         2923
# 1         2017-07-01       17812.11         2458
# 2         2017-08-01       13461.87         1721
# 3         2017-09-01       33682.56         3058
# 4         2017-10-01       27857.69         4678
# 5         2017-11-01       24426.72         4262
# 6         2017-12-01       31157.85         4074
# 7         2018-01-01       14546.82         3119
# 8         2018-02-01       15061.29         3186
# 9         2018-03-01       13770.16         2838
# 10        2018-04-01        9882.55         1890
# 11        2018-05-01       10371.53         2316

# %%
#proporcionLTV cuanto dinero aporta cada usuario que inicio secion por usuario cada mes por primera ves
df_ltv['ltv']=df_ltv['total_revenue']/df_ltv['total_users']
df_ltv=df_ltv.sort_values(by='primer_sesion_mes')
df_ltv
# Out:
#    primer_sesion_mes  total_revenue  total_users        ltv
# 0         2017-06-01       40026.05         2923  13.693483
# 1         2017-07-01       17812.11         2458   7.246587
# 2         2017-08-01       13461.87         1721   7.822121
# 3         2017-09-01       33682.56         3058  11.014572
# 4         2017-10-01       27857.69         4678   5.955043
# 5         2017-11-01       24426.72         4262   5.731281
# 6         2017-12-01       31157.85         4074   7.647975
# 7         2018-01-01       14546.82         3119   4.663937
# 8         2018-02-01       15061.29         3186   4.727335
# 9         2018-03-01       13770.16         2838   4.852065
# 10        2018-04-01        9882.55         1890   5.228862
# 11        2018-05-01       10371.53         2316   4.478208

# %%
df_ltv.set_index('primer_sesion_mes')['ltv'].plot(
    kind='bar',
    title='LTV por cohorte mensual ',
    ylabel='LTV promedio por usuario',
    xlabel='Mes de primera sesión',
    figsize=(10, 5),
    color='skyblue'
)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
cohort_size=compradores.groupby('first_orders_month').agg({'Uid':'nunique'}).reset_index()
cohort_size.rename(columns={'Uid':'n_buyers'},inplace=True)
cohort_size.head()
# Out:
#   first_orders_month  n_buyers
# 0            2017-06      2023
# 1            2017-07      1923
# 2            2017-08      1370
# 3            2017-09      2581
# 4            2017-10      4340

# %%
cohorts_=pd.merge(orders,compradores)

# %%
cohorts_=cohorts_.groupby(['first_orders_month','order_month']).agg({'Revenue':'sum'}).reset_index()

# %%
cohorts_['ciclo_de_vida']=(cohorts_['order_month'] - cohorts_['first_orders_month']).apply(lambda x:x.n)
cohorts_.head()
# Out:
#   first_orders_month order_month  Revenue  ciclo_de_vida
# 0            2017-06     2017-06  9557.49              0
# 1            2017-06     2017-07   981.82              1
# 2            2017-06     2017-08   885.34              2
# 3            2017-06     2017-09  1931.30              3
# 4            2017-06     2017-10  2068.58              4

# %%
cohorts_ltv=pd.merge(cohort_size, cohorts_)
cohorts_ltv['ltv']=cohorts_ltv['Revenue']/cohorts_ltv['n_buyers']
cohorts_ltv.head()
# Out:
#   first_orders_month  n_buyers order_month  Revenue  ciclo_de_vida       ltv
# 0            2017-06      2023     2017-06  9557.49              0  4.724414
# 1            2017-06      2023     2017-07   981.82              1  0.485329
# 2            2017-06      2023     2017-08   885.34              2  0.437637
# 3            2017-06      2023     2017-09  1931.30              3  0.954671
# 4            2017-06      2023     2017-10  2068.58              4  1.022531

# %%
LTV=cohorts_ltv.pivot_table(
    index='first_orders_month',
    columns='ciclo_de_vida',
    values='ltv',
    aggfunc='sum'
).cumsum(axis=1)
LTV.round(2).fillna('')
# Out:
# ciclo_de_vida         0     1     2      3      4      5      6      7   \
# first_orders_month
# 2017-06             4.72  5.21  5.65    6.6   7.62   8.36   9.31   9.89
# 2017-07             6.01  6.35  6.97   7.33    7.5   7.66   7.78   7.92
# 2017-08             5.28  5.75  6.21    6.6   7.09   7.38   7.59   7.99
# 2017-09             5.64  6.76  7.28  11.26  11.66  12.31  13.01  13.25
# 2017-10             5.00  5.54  5.73   5.89   6.04   6.16   6.24   6.36
# 2017-11             5.15  5.55  5.75   6.08   6.23   6.28    6.4
# 2017-12             4.74   5.0  5.92   6.99    7.3   7.64
# 2018-01             4.14  4.43  4.73   4.88   4.94
# 2018-02             4.16  4.44  4.51   4.59
# 2018-03             4.84  5.14  5.46
# 2018-04             4.66  5.19
# 2018-05             4.66
# 2018-06             3.42
#
# ciclo_de_vida          8      9      10     11
# first_orders_month
# 2017-06             10.45  11.05  11.62  11.88
# 2017-07              8.08   8.23   8.39
# ...

# %%
#dinero que traen LTV
sns.heatmap(LTV,annot=True)
plt.show()

# %% [markdown]
# 3. Marketing:
#
#
#  3.1. ¿Cuánto dinero se gastó?  (Total/por fuente de adquisición/a lo largo del tiempo)

# %% [markdown]
# COSTOS

# %%
#dineroquesegato total
costs['costs'].sum()
# Out:
# 329131.62

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source_id  2542 non-null   int64
#  1   dt         2542 non-null   object
#  2   costs      2542 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 59.7+ KB

# %%
costs['dt']=pd.to_datetime(costs['dt'])

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source_id  2542 non-null   int64
#  1   dt         2542 non-null   datetime64[ns]
#  2   costs      2542 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 59.7 KB

# %%
costs['cost_month']=costs['dt'].dt.to_period('M')
costs.head()
# Out:
#    source_id         dt  costs cost_month
# 0          1 2017-06-01  75.20    2017-06
# 1          1 2017-06-02  62.25    2017-06
# 2          1 2017-06-03  36.53    2017-06
# 3          1 2017-06-04  55.00    2017-06
# 4          1 2017-06-05  57.08    2017-06

# %%
costos_mes=costs.pivot_table(index='cost_month' ,values='costs',aggfunc='sum')
costos_mes
# Out:
#                costs
# cost_month
# 2017-06     18015.00
# 2017-07     18240.59
# 2017-08     14790.54
# 2017-09     24368.91
# 2017-10     36322.88
# 2017-11     37907.88
# 2017-12     38315.35
# 2018-01     33518.52
# 2018-02     32723.03
# 2018-03     30415.27
# 2018-04     22289.38
# 2018-05     22224.27

# %%
costos_mes.plot()
# Out:
# <AxesSubplot:xlabel='cost_month'>

# %%
costs.groupby('source_id').agg({'costs':'sum'})
# Out:
#                costs
# source_id
# 1           20833.27
# 2           42806.04
# 3          141321.63
# 4           61073.60
# 5           51757.10
# 9            5517.49
# 10           5822.49

# %%
#por fuente de adquisición
costs.pivot_table(index='cost_month' ,columns='source_id',values='costs',aggfunc='sum').plot.area(title='costos_por_fuente_de_adquisicion')
# Out:
# <AxesSubplot:title={'center':'costos_por_fuente_de_adquisicion'}, xlabel='cost_month'>

# %% [markdown]
#  3.2¿Cuál fue el costo de adquisición de clientes de cada una de las fuentes?

# %%
#cac general
costs['costs'].sum()/orders['Uid'].nunique()
# Out:
# 9.011626098622786

# %%
#cac mensual
cac_mensual=pd.merge(costs.groupby('cost_month').agg({'costs':'sum'}),
        compradores.groupby('first_orders_month').agg({'Uid':'nunique'}),
        left_index=True,
        right_index=True)
cac_mensual
# Out:
#             costs   Uid
# 2017-06  18015.00  2023
# 2017-07  18240.59  1923
# 2017-08  14790.54  1370
# 2017-09  24368.91  2581
# 2017-10  36322.88  4340
# 2017-11  37907.88  4081
# 2017-12  38315.35  4383
# 2018-01  33518.52  3373
# 2018-02  32723.03  3651
# 2018-03  30415.27  3533
# 2018-04  22289.38  2276
# 2018-05  22224.27  2988

# %%
cac_mensual['cac']=cac_mensual['costs']/cac_mensual['Uid']
cac_mensual
# Out:
#             costs   Uid        cac
# 2017-06  18015.00  2023   8.905091
# 2017-07  18240.59  1923   9.485486
# 2017-08  14790.54  1370  10.796015
# 2017-09  24368.91  2581   9.441654
# 2017-10  36322.88  4340   8.369327
# 2017-11  37907.88  4081   9.288870
# 2017-12  38315.35  4383   8.741809
# 2018-01  33518.52  3373   9.937302
# 2018-02  32723.03  3651   8.962758
# 2018-03  30415.27  3533   8.608907
# 2018-04  22289.38  2276   9.793225
# 2018-05  22224.27  2988   7.437841

# %%
cac_mensual['cac'].plot(title='promedio_del_cac_mensual')
# Out:
# <AxesSubplot:title={'center':'promedio_del_cac_mensual'}>

# %%
users=visits_completo.sort_values('primera_sesion_ts').groupby('Uid').first()
users=users[['Source Id']]
compradores=pd.merge(compradores, users, left_on='Uid',right_index=True)
compradores.head()
# Out:
#                 Uid   primera_sesion_ts primer_sesion_dia primer_sesion_mes  \
# 0   313578113262317 2017-09-18 22:49:00        2017-09-18        2017-09-01
# 1  1575281904278712 2017-06-03 10:13:00        2017-06-03        2017-06-01
# 2  2429014661409475 2017-10-11 17:14:00        2017-10-11        2017-10-01
# 3  2464366381792757 2018-01-27 20:10:00        2018-01-27        2018-01-01
# 4  2551852515556206 2017-11-24 10:14:00        2017-11-24        2017-11-01
#
#       first_orders_ts first_orders_dt first_orders_month  dias_primera_compra  \
# 0 2018-01-03 21:51:00      2018-01-03            2018-01                  106
# 1 2017-06-03 10:13:00      2017-06-03            2017-06                    0
# 2 2017-10-11 18:33:00      2017-10-11            2017-10                    0
# 3 2018-01-28 15:54:00      2018-01-28            2018-01                    0
# 4 2017-11-24 10:14:00      2017-11-24            2017-11                    0
#
#    Source Id
# 0          2
# ...

# %%
compradores_diarios=compradores.groupby(['Source Id','first_orders_dt']).agg({'Uid':'count'}).reset_index()
compradores_diarios.rename(columns={'Uid':'n_buyers'},inplace=True)
compradores_diarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Source Id        2463 non-null   int64
#  1   first_orders_dt  2463 non-null   datetime64[ns]
#  2   n_buyers         2463 non-null   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 57.9 KB

# %%
costs
# Out:
#       source_id         dt  costs cost_month
# 0             1 2017-06-01  75.20    2017-06
# 1             1 2017-06-02  62.25    2017-06
# 2             1 2017-06-03  36.53    2017-06
# 3             1 2017-06-04  55.00    2017-06
# 4             1 2017-06-05  57.08    2017-06
# ...         ...        ...    ...        ...
# 2537         10 2018-05-27   9.92    2018-05
# 2538         10 2018-05-28  21.26    2018-05
# 2539         10 2018-05-29  11.32    2018-05
# 2540         10 2018-05-30  33.15    2018-05
# 2541         10 2018-05-31  17.60    2018-05
#
# [2542 rows x 4 columns]

# %%
costos_=pd.merge(compradores_diarios,costs,left_on=['Source Id','first_orders_dt'],right_on=['source_id','dt'])
costos_['cac']=costos_['costs']/costos_['n_buyers']
cac_per_buyer=costos_.pivot_table(index='cost_month' ,columns='Source Id',values='cac',aggfunc='mean')
cac_per_buyer
# Out:
# Source Id         1          2          3          4          5         9   \
# cost_month
# 2017-06     8.253786  11.701073  18.162037  11.074003  10.608395  3.551010
# 2017-07     7.718060  14.957191  25.868170   8.079959   7.993750  4.905394
# 2017-08     7.582023  16.317285  23.178363  11.762548   7.189644  3.743753
# 2017-09     6.435300  12.107098  15.663983   9.571152   7.023470  5.992946
# 2017-10     6.814781  11.348321  16.020956   6.177559   6.731720  4.311377
# 2017-11     7.404181  11.881192  18.431435   5.493183  10.108440  5.717379
# 2017-12     5.334523  10.920709  14.983623   5.808416   8.882906  5.803617
# 2018-01     7.997958  12.819199  17.649703   6.088039   9.248228  6.822010
# 2018-02     7.331500  12.812067  15.327533   5.922242   7.737428  7.595461
# 2018-03     5.696780  11.893724  18.134424   7.694554   9.090628  4.913088
# 2018-04     6.376562  14.862893  18.001880   7.008081  10.354653  8.071079
# ...

# %%
cac_per_buyer.plot(title='cac_por_comprador_por_fuente')
# Out:
# <AxesSubplot:title={'center':'cac_por_comprador_por_fuente'}, xlabel='cost_month'>

# %%
compradores_diarios
# Out:
#       Source Id first_orders_dt  n_buyers
# 0             1      2017-06-01        15
# 1             1      2017-06-02        11
# 2             1      2017-06-03         7
# 3             1      2017-06-04         4
# 4             1      2017-06-05        14
# ...         ...             ...       ...
# 2458         10      2018-05-27         2
# 2459         10      2018-05-28         9
# 2460         10      2018-05-29         6
# 2461         10      2018-05-30         5
# 2462         10      2018-05-31        35
#
# [2463 rows x 3 columns]

# %% [markdown]
#  3. ¿Cuán rentables eran las inversiones? (ROMI)

# %%
cac_per_buyer
# Out:
# Source Id         1          2          3          4          5         9   \
# cost_month
# 2017-06     8.253786  11.701073  18.162037  11.074003  10.608395  3.551010
# 2017-07     7.718060  14.957191  25.868170   8.079959   7.993750  4.905394
# 2017-08     7.582023  16.317285  23.178363  11.762548   7.189644  3.743753
# 2017-09     6.435300  12.107098  15.663983   9.571152   7.023470  5.992946
# 2017-10     6.814781  11.348321  16.020956   6.177559   6.731720  4.311377
# 2017-11     7.404181  11.881192  18.431435   5.493183  10.108440  5.717379
# 2017-12     5.334523  10.920709  14.983623   5.808416   8.882906  5.803617
# 2018-01     7.997958  12.819199  17.649703   6.088039   9.248228  6.822010
# 2018-02     7.331500  12.812067  15.327533   5.922242   7.737428  7.595461
# 2018-03     5.696780  11.893724  18.134424   7.694554   9.090628  4.913088
# 2018-04     6.376562  14.862893  18.001880   7.008081  10.354653  8.071079
# ...

# %%
LTV.index
# Out:
# PeriodIndex(['2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11',
#              '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
#              '2018-06'],
#             dtype='period[M]', name='first_orders_month', freq='M')

# %%
romi=(LTV - cac_per_buyer)/(cac_per_buyer)
romi
# Out:
#          0         1         2         3         4         5   6   7   8   \
# 2017-06 NaN -0.368806 -0.517362 -0.636492 -0.311488 -0.211937 NaN NaN NaN
# 2017-07 NaN -0.177847 -0.534073 -0.716720 -0.071192 -0.041654 NaN NaN NaN
# 2017-08 NaN -0.241824 -0.619606 -0.715326 -0.397042  0.025901 NaN NaN NaN
# 2017-09 NaN  0.050785 -0.398448 -0.281228  0.218181  0.752191 NaN NaN NaN
# 2017-10 NaN -0.187135 -0.495001 -0.632479 -0.022333 -0.084936 NaN NaN NaN
# 2017-11 NaN -0.249895 -0.515750 -0.670214  0.133484 -0.378706 NaN NaN NaN
# 2017-12 NaN -0.062978 -0.457575 -0.533562  0.257118 -0.139931 NaN NaN NaN
# 2018-01 NaN -0.446059 -0.630657 -0.723652 -0.188548       NaN NaN NaN NaN
# 2018-02 NaN -0.395040 -0.647693 -0.700675       NaN       NaN NaN NaN NaN
# 2018-03 NaN -0.097790 -0.541333       NaN       NaN       NaN NaN NaN NaN
# 2018-04 NaN -0.186208       NaN       NaN       NaN       NaN NaN NaN NaN
# 2018-05 NaN       NaN       NaN       NaN       NaN       NaN NaN NaN NaN
# ...

# %%
sns.heatmap(romi,annot=True, mask=romi.isna())
plt.show()

# %%
LTV.mean()
# Out:
# ciclo_de_vida
# 0      4.801682
# 1      5.395666
# 2      5.821811
# 3      6.689763
# 4      7.298634
# 5      7.969053
# 6      8.387686
# 7      9.083583
# 8     10.062084
# 9      9.251340
# 10    10.004616
# 11    11.879234
# dtype: float64

# %%
LTV_2=LTV.reset_index().melt(id_vars='first_orders_month',var_name='ciclo_de_vida',value_name='LTV')
LTV_2=LTV_2.rename(columns={'first_orders_month':'cohorte'})
LTV_2=LTV_2.fillna(0)
LTV_2
# Out:
#      cohorte  ciclo_de_vida       LTV
# 0    2017-06              0  4.724414
# 1    2017-07              0  6.010218
# 2    2017-08              0  5.276518
# 3    2017-09              0  5.644529
# 4    2017-10              0  5.003733
# ..       ...            ...       ...
# 151  2018-02             11  0.000000
# 152  2018-03             11  0.000000
# 153  2018-04             11  0.000000
# 154  2018-05             11  0.000000
# 155  2018-06             11  0.000000
#
# [156 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Has implementado correctamente el cálculo del LTV por cohorte mensual. El uso de `groupby` para calcular los ingresos y usuarios por cohorte y luego derivar el LTV con una simple división muestra un buen dominio técnico.
#
# Además, presentas el LTV mensual tanto como valor puntual como acumulado, lo cual es muy valioso para analizar la rentabilidad a lo largo del tiempo. El gráfico tipo barra es una elección adecuada para comparar LTV entre cohorts. Este análisis agrega una capa estratégica importante al proyecto. Bien hecho.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Muy buen trabajo en el cálculo del LTV, pero es importante mejorar la consistencia en los nombres de tus variables:
#
# - Algunas variables como `LTV`, `ROMI`, `Revenue` están en mayúsculas, lo cual por convención en Python se reserva para constantes globales. Para variables normales, se recomienda usar minúsculas con guiones bajos, por ejemplo: `ltv`, `romi`, `revenue`.
# - Además, evitemos mezclar inglés y español en los nombres (`first_orders_month` vs `primer_sesion_mes`, `cohort_size` vs `compradores_diarios`). Elegir un solo idioma para todo el proyecto (preferiblemente inglés en contextos profesionales) ayuda a mantener claridad y estilo.
#
# Unificar estas prácticas hará tu código más limpio, legible y profesional. ¡Estás muy cerca de un estándar excelente!
#
# </div>

# %%
CAC_2=cac_per_buyer.reset_index().melt(id_vars='cost_month',var_name='Source Id',value_name='cac')
CAC_2=CAC_2.rename(columns={'cost_month':'cohorte'})
CAC_2=CAC_2.fillna(0)
CAC_2
# Out:
#     cohorte  Source Id        cac
# 0   2017-06          1   8.253786
# 1   2017-07          1   7.718060
# 2   2017-08          1   7.582023
# 3   2017-09          1   6.435300
# 4   2017-10          1   6.814781
# ..      ...        ...        ...
# 79  2018-01         10  11.247962
# 80  2018-02         10   4.594337
# 81  2018-03         10   5.747988
# 82  2018-04         10   4.254129
# 83  2018-05         10   5.159384
#
# [84 rows x 3 columns]

# %%
romi_2=pd.merge(CAC_2,LTV_2,on='cohorte')
romi_2
# Out:
#       cohorte  Source Id       cac  ciclo_de_vida       LTV
# 0     2017-06          1  8.253786              0  4.724414
# 1     2017-06          1  8.253786              1  5.209743
# 2     2017-06          1  8.253786              2  5.647380
# 3     2017-06          1  8.253786              3  6.602051
# 4     2017-06          1  8.253786              4  7.624582
# ...       ...        ...       ...            ...       ...
# 1003  2018-05         10  5.159384              7  0.000000
# 1004  2018-05         10  5.159384              8  0.000000
# 1005  2018-05         10  5.159384              9  0.000000
# 1006  2018-05         10  5.159384             10  0.000000
# 1007  2018-05         10  5.159384             11  0.000000
#
# [1008 rows x 5 columns]

# %%
romi_2['ROMI'] = (romi_2['LTV'] - romi_2['cac']) / romi_2['cac']
romi_2
# Out:
#       cohorte  Source Id       cac  ciclo_de_vida       LTV      ROMI
# 0     2017-06          1  8.253786              0  4.724414 -0.427606
# 1     2017-06          1  8.253786              1  5.209743 -0.368806
# 2     2017-06          1  8.253786              2  5.647380 -0.315783
# 3     2017-06          1  8.253786              3  6.602051 -0.200118
# 4     2017-06          1  8.253786              4  7.624582 -0.076232
# ...       ...        ...       ...            ...       ...       ...
# 1003  2018-05         10  5.159384              7  0.000000 -1.000000
# 1004  2018-05         10  5.159384              8  0.000000 -1.000000
# 1005  2018-05         10  5.159384              9  0.000000 -1.000000
# 1006  2018-05         10  5.159384             10  0.000000 -1.000000
# 1007  2018-05         10  5.159384             11  0.000000 -1.000000
#
# [1008 rows x 6 columns]

# %%
#grafico calor barras y boxplot

# %%
romi_2
# Out:
#       cohorte  Source Id       cac  ciclo_de_vida       LTV      ROMI
# 0     2017-06          1  8.253786              0  4.724414 -0.427606
# 1     2017-06          1  8.253786              1  5.209743 -0.368806
# 2     2017-06          1  8.253786              2  5.647380 -0.315783
# 3     2017-06          1  8.253786              3  6.602051 -0.200118
# 4     2017-06          1  8.253786              4  7.624582 -0.076232
# ...       ...        ...       ...            ...       ...       ...
# 1003  2018-05         10  5.159384              7  0.000000 -1.000000
# 1004  2018-05         10  5.159384              8  0.000000 -1.000000
# 1005  2018-05         10  5.159384              9  0.000000 -1.000000
# 1006  2018-05         10  5.159384             10  0.000000 -1.000000
# 1007  2018-05         10  5.159384             11  0.000000 -1.000000
#
# [1008 rows x 6 columns]

# %%
#sns.heatmap(romi_2,annot=True, mask=romi_2.isna())
#plt.show()

# %%
#romi_2.index = romi_2.index.astype(str)  # If index is Period
#romi_2.columns = romi_2.columns.astype(str)  # If columns are Period

#sns.heatmap(romi_2, annot=True, mask=romi_2.isna())
#plt.show()

# %%
romi_2_numerico = romi_2.apply(pd.to_numeric, errors='coerce')

sns.heatmap(romi_2_numerico, annot=True, mask=romi_2_numerico.isna())
plt.show()

# %%
#ROMI#report_['romi'] =report_['ltv'] / report_['cac']
#.pivot_table(index='' ,colums='',values='',aggfun='')

# %%
#heatmap()

# %%
month_revenue=orders.groupby(['Uid','order_month']).agg({'Revenue':'sum'}).reset_index()
compradores=compradores.merge(month_revenue,on='Uid')
compradores
# Out:
#                         Uid   primera_sesion_ts primer_sesion_dia  \
# 0           313578113262317 2017-09-18 22:49:00        2017-09-18
# 1          1575281904278712 2017-06-03 10:13:00        2017-06-03
# 2          2429014661409475 2017-10-11 17:14:00        2017-10-11
# 3          2464366381792757 2018-01-27 20:10:00        2018-01-27
# 4          2551852515556206 2017-11-24 10:14:00        2017-11-24
# ...                     ...                 ...               ...
# 41014  18445147675727495770 2017-08-20 13:30:00        2017-08-20
# 41015  18445407535914413204 2017-09-22 23:48:00        2017-09-22
# 41016  18445601152732270159 2017-08-07 11:51:00        2017-08-07
# 41017  18446156210226471712 2017-11-07 10:01:00        2017-11-07
# 41018  18446167067214817906 2017-10-17 10:05:00        2017-10-17
#
#       primer_sesion_mes     first_orders_ts first_orders_dt  \
# 0            2017-09-01 2018-01-03 21:51:00      2018-01-03
# ...

# %%
for source,df in compradores.groupby('Source Id'):
    if source !=7:
        cohort_size=(
            df.groupby(['Source Id','first_orders_month'])
            .agg({'Uid':'nunique'})
            .reset_index()
            
        )
        cohort_size.columns=['source_id','first_orders_month','n_buyers']
        cohort_revenue=(
            df.groupby(['Source Id','first_orders_month','order_month'])
            .agg({'Revenue':'sum'})
            .reset_index()
        )
        cohort_revenue.columns=['source_id','first_orders_month','order_month','gp']

        report_romi=pd.merge(cohort_size,cohort_revenue,on=['source_id','first_orders_month'])
        report_romi['ciclo_de_vida']=(report_romi['order_month'] - report_romi['first_orders_month']).apply(lambda x:x.n)
        report_romi['ciclo_de_vida']=report_romi['ciclo_de_vida'].round().astype('int')
        report_romi['ltv']=report_romi['gp']/report_romi['n_buyers']
        report_romi=pd.merge(report_romi,costs.groupby(['source_id','cost_month']).agg({'costs':'sum'}).reset_index(),
                             left_on=['source_id','first_orders_month'],right_on=['source_id','cost_month'])
        report_romi=report_romi.drop(['cost_month'],axis=1)
        report_romi['cac']=report_romi['costs']/report_romi['n_buyers']
        report_romi['romi']=report_romi['ltv']/report_romi['cac']

        romi=report_romi.pivot_table(
            index='first_orders_month',
            columns='ciclo_de_vida',
            values='romi',
            aggfunc='mean'
        ).cumsum(axis=1)
        romi.round(2).fillna('')
        
        romi.index=romi.index.astype(str)
        sns.heatmap(romi,annot=True,fmt='.2f',linewidths=1).set(title='romi_por_fuente{}'.format(source))
        plt.show()

# %%
costs
# Out:
#       source_id         dt  costs cost_month
# 0             1 2017-06-01  75.20    2017-06
# 1             1 2017-06-02  62.25    2017-06
# 2             1 2017-06-03  36.53    2017-06
# 3             1 2017-06-04  55.00    2017-06
# 4             1 2017-06-05  57.08    2017-06
# ...         ...        ...    ...        ...
# 2537         10 2018-05-27   9.92    2018-05
# 2538         10 2018-05-28  21.26    2018-05
# 2539         10 2018-05-29  11.32    2018-05
# 2540         10 2018-05-30  33.15    2018-05
# 2541         10 2018-05-31  17.60    2018-05
#
# [2542 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente cierre técnico antes de las conclusiones. El análisis de ROMI está bien fundamentado y demuestra una comprensión clara del impacto del marketing en la rentabilidad. La implementación es sólida: calculas correctamente el ROMI como `(LTV - CAC) / CAC` y usas `pivot_table` y `heatmap` para mostrar su evolución por cohorte y ciclo de vida.
#
# </div>

# %% [markdown]
# concluciones
# ¿Qué fuentes/plataformas recomendarías?
# explicari que seria por los numeric
#
#
# ¿en qué métricas te enfocaste?  ¿Por qué?
# ¿Qué conclusiones sacaste después de encontrar los valores métricos?

# %% [markdown]
# romi por ciclos de vida cada uno:
# romi_por_fuente1:sinduda hay ganacias alrededor de 2017-06se registran los numeros mas altos pero alrededo de2018-05 la ganacia ya no parece superior ala de la invercion es buena pero en un cilo de un año
# el romi porfuente2: solo presenta alta arededor del mes
#
# enla fuente2hayuna escala muy alta en2017-09 pero el resto esta muy bajo
# Fuente 3,  Fuente 5,4y 9 parecen mas estables

# %% [markdown]
# las mericas principales fueron las medidas de tasasderetentencion LTV(life time value) Y ROMI(Return on Marketing Investment) retotorno de la invercion. atraves de los 3 datasets para definir la ganacias alo largo del plaso y su rentabilidad,

# %% [markdown]
# enlos valore metricos se llego a las concluciones diferentes :
# principalmente en que si es posible optimisar los gastos todo es con probabilidad de riesgo pero a lo largo es seguro las ganancias

# %% [markdown]
# una conclucion mas es que es probable quetenga demaciada informacion y hay probabilidad de errores tambien quedaron algunos errores del pasado quese corrigieron durante el transcurso del proyecto

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades! Tu proyecto está <b>aprobado</b>. Has demostrado un análisis completo, bien fundamentado y con una ejecución técnica sólida. Los cálculos de cohortes, LTV, CAC y ROMI están bien implementados y las visualizaciones apoyan muy bien la interpretación de resultados.
#
# <h4>Puntos Positivos:</h4>
# <ul>
#   <li><b>Procesamiento de cohortes:</b> Cálculos bien estructurados para analizar comportamiento y valor de cliente a lo largo del tiempo.</li>
#   <li><b>Métricas clave bien aplicadas:</b> Muy buen uso de LTV, CAC y ROMI con visualizaciones útiles y bien interpretadas.</li>
#   <li><b>Fusión e integración de datasets:</b> Correcto uso de `merge`, `groupby` y `pivot_table` para consolidar información y generar insights.</li>
# </ul>
#
# <h4>Área de mejora:</h4>
# <ul>
#   <li><b>Consistencia en Markdown:</b> En algunas secciones usas buenos títulos y explicaciones, pero en otras no hay separación visual o los encabezados no siguen un mismo estilo. Trata de mantener una estructura uniforme con títulos (`##`), subtítulos (`###`) y comentarios descriptivos para que el notebook sea más legible y profesional.</li>
# </ul>
#
# ¡Sigue así! Este proyecto está muy cerca del nivel profesional. Con pequeñas mejoras de estilo, tu trabajo se destacará aún más. 🚀📊✨
#
# </div>
